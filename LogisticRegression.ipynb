# %% [markdown]
# <a href="https://colab.research.google.com/github/sushant1911/Machine-Learning/blob/master/LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from  google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-354e86cb-8433-4ec4-955b-92e1a4ea4e09" name="files[]" multiple disabled />
#      <output id="result-354e86cb-8433-4ec4-955b-92e1a4ea4e09">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving titanic_train.csv to titanic_train (1).csv

# %%
import io
import pandas as pd
df=pd.read_csv(io.BytesIO(upload['titanic_train.csv']))
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
# 5            6         0       3  ...   8.4583   NaN         Q
# 6            7         0       1  ...  51.8625   E46         S
# 7            8         0       3  ...  21.0750   NaN         S
# 8            9         1       3  ...  11.1333   NaN         S
# 9           10         1       2  ...  30.0708   NaN         C
#
# [10 rows x 12 columns]

# %%
import seaborn as sb
sb.pairplot(df)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
import seaborn as sb
sb.heatmap(df.isnull(),cmap='viridis')

# %%
sb.countplot(x='Survived',hue='Sex',data=df)

# %%
sb.boxplot(x='Pclass',y='Age',data=df,fliersize=(10))

# %%
df.fillna(df.mean(), inplace=True)

# %%
df.drop("Cabin",inplace=True,axis=1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.figure(figsize=(10,7))
sb.countplot(x='Pclass',hue='Sex',data=df)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0            1         0       3  ...         A/5 21171   7.2500         S
# 1            2         1       1  ...          PC 17599  71.2833         C
# 2            3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3            4         1       1  ...            113803  53.1000         S
# 4            5         0       3  ...            373450   8.0500         S
#
# [5 rows x 11 columns]

# %%
sex=pd.get_dummies(df["Sex"],drop_first=True)

# %%
df.dropna(inplace=True)

# %%
embarked = pd.get_dummies(df["Embarked"],drop_first=True)
pclass = pd.get_dummies(df["Pclass"],drop_first=True)

# %%
df = pd.concat([df,pclass,sex,embarked],axis=1)
df
# Out:
#      PassengerId  Survived  Pclass  ... male  Q  S
# 0              1         0       3  ...    1  0  1
# 1              2         1       1  ...    0  0  0
# 2              3         1       3  ...    0  0  1
# 3              4         1       1  ...    0  0  1
# 4              5         0       3  ...    1  0  1
# 5              6         0       3  ...    1  1  0
# 6              7         0       1  ...    1  0  1
# 7              8         0       3  ...    1  0  1
# 8              9         1       3  ...    0  0  1
# 9             10         1       2  ...    0  0  0
# 10            11         1       3  ...    0  0  1
# 11            12         1       1  ...    0  0  1
# 12            13         0       3  ...    1  0  1
# 13            14         0       3  ...    1  0  1
# 14            15         0       3  ...    0  0  1
# 15            16         1       2  ...    0  0  1
# 16            17         0       3  ...    1  1  0
# ...

# %%
df.drop(["PassengerId","Pclass","Name","Sex","Ticket","Embarked"],axis=1,inplace=True)

# %%
sb.heatmap(df.isnull())

# %%
X = df.drop("Survived",axis=1)
y = df["Survived"]

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from sklearn.model_selection import cross_validate
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)
 
print(X_train, X_test, y_train, y_test)

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression(solver='lbfgs')
logmodel.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
logmodel.score(X_train,y_train)
# Out:
# 0.812199036918138

# %%
predictions = logmodel.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       157
#            1       0.80      0.68      0.74       111
#
#     accuracy                           0.80       268
#    macro avg       0.80      0.78      0.79       268
# weighted avg       0.80      0.80      0.80       268
