# %% [markdown]
# <a href="https://colab.research.google.com/github/sushant1911/Machine-Learning/blob/master/decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
file=files.upload()
# Out:
#      <input type="file" id="files-d8faaaf2-86ce-4fff-966c-3a1af3ea802d" name="files[]" multiple disabled />
#      <output id="result-d8faaaf2-86ce-4fff-966c-3a1af3ea802d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kyphosis.csv to kyphosis.csv

# %%
import pandas as pd
import io
df=pd.read_csv(io.BytesIO(file['kyphosis.csv']))
df['Kyphosis'].value_counts()
# Out:
# absent     64
# present    17
# Name: Kyphosis, dtype: int64

# %%
import seaborn as sb
sb.pairplot(df,hue='Kyphosis')

# %%
x=df.drop('Kyphosis',axis=1)
y=df['Kyphosis']

# %%
from sklearn.model_selection import KFold
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.33)

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()

# %%
tree.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
tree.score(xtrain,ytrain)
# Out:
# 1.0

# %%
prediction=tree.predict(xtest)

# %%
from sklearn.metrics import  classification_report,confusion_matrix
print(classification_report(prediction,ytest))
print("\n")
print(confusion_matrix(prediction,ytest))
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.85      0.77      0.81        22
#      present       0.29      0.40      0.33         5
#
#     accuracy                           0.70        27
#    macro avg       0.57      0.59      0.57        27
# weighted avg       0.75      0.70      0.72        27
#
#
#
# [[17  5]
#  [ 3  2]]

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=200)

# %%
rf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
Rfprediction=tree.predict(xtest)

# %%
print(classification_report(Rfprediction,ytest))
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.85      0.77      0.81        22
#      present       0.29      0.40      0.33         5
#
#     accuracy                           0.70        27
#    macro avg       0.57      0.59      0.57        27
# weighted avg       0.75      0.70      0.72        27
